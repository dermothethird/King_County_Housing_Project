# %%
# Import standard packages
import itertools
import numpy as np
import pandas as pd 
from numbers import Number
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.preprocessing import StandardScaler, OneHotEncoder
# %matplotlib inline

# %%
# Import the data
df = pd.read_csv("./data/ln_price_dataframe")
df
# Out:
#                id        date   ln_price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  12.309982         3       1.00         1180
# 1      6414100192   12/9/2014  13.195614         3       2.25         2570
# 2      5631500400   2/25/2015  12.100712         2       1.00          770
# 3      2487200875   12/9/2014  13.311329         4       3.00         1960
# 4      1954400510   2/18/2015  13.142166         3       2.00         1680
# ...           ...         ...        ...       ...        ...          ...
# 21592   263000018   5/21/2014  12.793859         3       2.50         1530
# 21593  6600060120   2/23/2015  12.899220         4       2.50         2310
# 21594  1523300141   6/23/2014  12.904459         2       0.75         1020
# 21595   291310100   1/16/2015  12.899220         3       2.50         1600
# 21596  1523300157  10/15/2014  12.691580         2       0.75         1020
#
# ...

# %%
df['date'].value_counts()
# Out:
# 6/23/2014    142
# 6/25/2014    131
# 6/26/2014    131
# 7/8/2014     127
# 4/27/2015    126
#             ...
# 8/3/2014       1
# 3/8/2015       1
# 5/15/2015      1
# 2/15/2015      1
# 5/24/2015      1
# Name: date, Length: 372, dtype: int64

# %%
df1 = df.drop(df[['date', 'view', 'waterfront','condition','grade','zipcode','lat', 'long' ]], axis = 1)
df1.head()
# Out:
#            id   ln_price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  12.309982         3       1.00         1180      5650     1.0
# 1  6414100192  13.195614         3       2.25         2570      7242     2.0
# 2  5631500400  12.100712         2       1.00          770     10000     1.0
# 3  2487200875  13.311329         4       3.00         1960      5000     1.0
# 4  1954400510  13.142166         3       2.00         1680      8080     1.0
#
#    sqft_above sqft_basement  yr_built  yr_renovated  sqft_living15  sqft_lot15
# 0        1180           0.0      1955           0.0           1340        5650
# 1        2170         400.0      1951        1991.0           1690        7639
# 2         770           0.0      1933           NaN           2720        8062
# 3        1050         910.0      1965           0.0           1360        5000
# 4        1680           0.0      1987           0.0           1800        7503

# %%
fig,ax = plt.subplots()
plt.style.use('seaborn')
sns.set_context('talk')
df.plot(kind = 'scatter',x = 'long', y = 'lat', alpha = 0.4 , c = 'price', cmap=plt.get_cmap('jet'), colorbar = True, vmin = 0, vmax = 1e6, figsize = (15,7),ax=ax);
#df_full_set.iloc[[10247]].plot(kind = 'scatter',x = 'long', y = 'lat', alpha = 0.4 , c = 'price', cmap=plt.get_cmap('jet'), colorbar = True, vmin = 0, vmax = 1e6, figsize = (15,7),ax=ax);

ax.grid(False)
ax.set_facecolor('White')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
#ax.set_xlim(-122.4,-121.4)
#ax.set_ylim(47.1,47.8)
ax.set_title('Property Prices in King County');
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError as err:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/colors.py in <listcomp>(.0)
#     324         try:
# --> 325             result = np.array([to_rgba(cc, alpha) for cc in c])
#     326         except ValueError as err:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     188     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 189         rgba = _to_rgba_no_colorcycle(c, alpha)
#     190         try:
#
# ...
